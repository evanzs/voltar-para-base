// %% [markdown]
// Trabalhando com funções em Typescript:

// %% [markdown]
// Formas de declarar funções e varaiveis recebidas por parametros

// %%
function add (a:number, b = 5){
    return a + b
}


console.log(add(10))
console.log(add('10')) // erro de tipo 
console.log(add(10,6));
console.log(add(10,'6')); // erro de tipo



//OBS: Note como é DENO ele não irá representar o erro mas calculo estará errado.
// Out:
// 15
// 105
// 16
// 106

// %% [markdown]
// Teste de função sem passar um valor constado no B

// %%
function add (a: number, b: number){
    return a + b
}

console.log(add(10)) // erro falta variavel de parametro
console.log(add('10')) // erro de tipo 
console.log(add(10,6));
console.log(add(10,'6')); // erro de tipo
// Out:
// NaN
// 10undefined
// 16
// 106

// %% [markdown]
// Trabalhando com o conceito de Tipo Flexiveis e Union Type

// %%
// TIPO FLEXIVEL ANY não é rrecomendado:

let teste: any = 'teste'

console.log(typeof teste,teste)

teste = 38;
console.log(typeof teste,teste)

teste = {}
console.log(typeof teste,teste)


teste = [38]
console.log(typeof teste,teste)
// Out:
// string teste
// number 38
// object {}
// object [ 38 ]

// %%
// TIPO UNIAO

let teste:  string | number;  // a variavel pode ser um ou outro


teste = 40;
console.log(typeof teste,teste)

teste= '40'
console.log(typeof teste,teste)


teste = 40;
console.log(typeof teste,teste + 1)

teste= '40'
console.log(typeof teste,teste + 2)
// Out:
// number 40
// string 40
// number 41
// string 402

// %% [markdown]
// Trabalhando com Arrays e Objetos

// %%
let hobbies = ['Sport','Cooking']

hobbies.push('Games')

console.log(typeof hobbies,hobbies)


hobbies = [2,3]

//hobbies.push('Games') // erro

console.log(typeof hobbies,hobbies)


let users: (string|number)[] // array de string ou numeros
let mesmaAbordagem: Array <string | number>;

users = [1,'MAXXISSUEL']

console.log(typeof users,users)
// Out:
// object [ "Sport", "Cooking", "Games" ]
// object [ 2, 3 ]
// object [ 1, "MAXXISSUEL" ]

// %% [markdown]
// TRABALHANDO COM TUPLAS EM TYPESCRIPT

// %%
let users: Array<string | number>; // aceita os dois tipos 

users = ['MAX',1]; // primeiro tipo de tupla hetero.
console.log(users)

users = [1,2]; //
console.log(users)
// Out:
// [ "MAX", 1 ]
// [ 1, 2 ]

// %%
let users: [number , number]; // aceita os dois number apenas 

users = ['MAX',1]; // errado
console.log(users)

users = [1,2]; // certo
console.log(users)


users = [1,2,4]; // erro
console.log(users)
// Out:
// [ "MAX", 1 ]
// [ 1, 2 ]
// [ 1, 2, 4 ]

// %% [markdown]
// Trabalhando com Enums

// %%
enum Role1 {
    Admin, // 0
    Editor, // 1
    Quest,// 2
}

// aparece sem erro, assumindo a posição 0 = Admin
let userRole1: Role1 = 0;
console.log(userRole)
userRole = Role1.Editor;

console.log(userRole1)
// Out:
// 0
// 1
