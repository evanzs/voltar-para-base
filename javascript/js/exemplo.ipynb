// %%
console.log("Teste")
// Out:
// Teste

// %%
[{teste:"teste"},{teste:"teste"},{teste:"teste"}].map( (t) =>  (console.log(t.teste)))
// Out:
// teste
// teste
// teste
// [ undefined, undefined, undefined ]

// %% [markdown]
// [{teste:"teste"},{teste:"testet"},{teste:"teste"}].filter( (t) =>  t.teste ==== 'testet)
